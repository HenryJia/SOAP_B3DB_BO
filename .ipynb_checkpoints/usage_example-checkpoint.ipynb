# %% [markdown]
# ## Before running

# %% [markdown]
# In order to keep the GA code consistently usable on Avon, I have created a virtual environment consistent with the python packages on Avon. To use this environment you need to install pipenv with
# - 'pip install pipenv'
#
# Then to create a virtual environment with all the required packages run
# - 'pipenv install'
#
# To activate the environment run
# - 'pipenv shell'
#
# You can now run the GA code. To exit the virtual environment just use
# - 'exit'
#
# All the required packages are listed in 'SOAP_GAS_TMS/Pipfile'

# %%
from genetic_algorithm import *

# %% [markdown]
# ## Get atomic species

# %%
def get_atomicnumbers(xyz_data):
    atomic_numbers=[]
    for mol in xyz_data:    
        atomic_numbers.extend(mol.get_atomic_numbers())
    return list(set(atomic_numbers))

# %%
path="EXAMPLES/Classification/"
data=pd.read_csv(path+"database.csv")
names=data["Name"].values


moles={}
for name in names:
    moles[name]=ase.io.read(path+"xyz/{}.xyz".format(name))


species=get_atomicnumbers(moles.values())
print("Classification species:",species)
# Out:
# Classification species: [1, 6, 7, 8, 9, 15, 16, 17]

# %%
path="EXAMPLES/Regression/"
data=pd.read_csv(path+"database.csv")
names=data["Name"].values


moles={}
for name in names:
    moles[name]=ase.io.read(path+"xyz/{}.xyz".format(name))


species=get_atomicnumbers(moles.values())
print("Regression species:",species)
# Out:
# Regression species: [1, 6, 7, 8, 9, 15, 16, 17]

# %% [markdown]
# ## Inputs

# %% [markdown]
# Dictionaries are taken as input from a parameter file, they contain the parameters for each soap descriptor

# %%
descDict1 = {'lower': 1, 'upper': 10, 'centres': '{1, 6, 7, 8, 9, 15, 16, 17}',
             'neighbours': '{1, 6, 7, 8, 9, 15, 16, 17}', 'mu': 0, 
             'mu_hat': 0, 'nu': 2, 'nu_hat': 0, 'mutation_chance': 0.50, 
             'min_cutoff': 4, 'max_cutoff': 10, 'min_sigma': 0.1, 
             'max_sigma': 0.9, 'message_steps': 8}

descDict2 = {'lower': 1, 'upper': 5, 'centres': '{1, 6, 7, 8, 9, 15, 16, 17}',
             'neighbours': '{1, 6, 7, 8, 9, 15, 16, 17}', 'mu': 0, 
             'mu_hat': 0, 'nu': 2, 'nu_hat': 0, 'mutation_chance': 0.50, 
             'min_cutoff': 4, 'max_cutoff': 5, 'min_sigma': 0.1, 
             'max_sigma': 0.9, 'message_steps': 10}

# %% [markdown]
# Other parameters are also taken as input. These are automatically checked that the parameters are viable

# %%
num_gens = 5
best_sample, lucky_few, population_size, number_of_children = 4, 2, 12, 4
early_stop = 2
early_number = 3 
min_generations = 5

# %% [markdown]
# ## GeneParameter

# %% [markdown]
# GeneParameter class is created from each descriptor dictionary.

# %%
params1 = GeneParameters(**descDict1)
params2 = GeneParameters(**descDict2)

# %%
params1
# Out:
# GeneParameters(lower=1, upper=10, centres='{1, 6, 7, 8, 9, 15, 16, 17}', neighbours='{1, 6, 7, 8, 9, 15, 16, 17}', mu=0, mu_hat=0, nu=2, nu_hat=0, mutation_chance=0.5, min_cutoff=4, max_cutoff=10, min_sigma=0.1, max_sigma=0.9, message_steps=8)

# %% [markdown]
# ## GeneSet

# %% [markdown]
# We can use these classes to create a specific set of parameters that are consistant with these values. This returns a randomly generated GeneSet class

# %%
example_gene_set = params1.make_gene_set()
example_gene_set
# Out:
# GeneSet(4, 1, 4, 0.66)

# %% [markdown]
# We can get the parameters used to create the GeneSet class

# %%
example_gene_set.gene_parameters
# Out:
# GeneParameters(lower=1, upper=10, centres='{1, 6, 7, 8, 9, 15, 16, 17}', neighbours='{1, 6, 7, 8, 9, 15, 16, 17}', mu=0, mu_hat=0, nu=2, nu_hat=0, mutation_chance=0.5, min_cutoff=4, max_cutoff=10, min_sigma=0.1, max_sigma=0.9, message_steps=8)

# %% [markdown]
# We can get a descriptor string to be used as an input for getting SOAPs

# %%
example_gene_set.get_soap_string()
# Out:
# 'soap cutoff=4 l_max=1 n_max=4 atom_sigma=0.66 n_Z=8 Z={1, 6, 7, 8, 9, 15, 16, 17} n_species=8 species_Z={1, 6, 7, 8, 9, 15, 16, 17} mu=0 mu_hat=0 nu=2 nu_hat=0'

# %% [markdown]
# We can also mutate the gene using the mutation chance in the GeneParameters class

# %%
print(f"Before mutation {example_gene_set}")
example_gene_set.mutate_gene()
print(f"After mutation {example_gene_set}")
# Out:
# Before mutation [4, 1, 4, 0.66]
# After mutation [4, 7, 4, 0.68]

# %% [markdown]
# ## Individual

# %% [markdown]
# An Individual is made up of a list of GeneSet classes.

# %%
example_gene_set_two = params2.make_gene_set()
gene_set_list = [example_gene_set, example_gene_set_two]
example_individual = Individual(gene_set_list[:1])
example_individual
# Out:
# Individual(['GeneSet(4, 7, 4, 0.68)'])

# %% [markdown]
# Getting the score for an indivudual

# %%
example_individual.get_score()
example_individual.score
# Out:
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Doing multiple message passes 8 times
# Epoch 1/200
# 4/4 [==============================] - 1s 68ms/step - loss: 1.4471 - accuracy: 0.2549 - val_loss: 1.0723 - val_accuracy: 0.4615
# Epoch 2/200
# 4/4 [==============================] - 0s 13ms/step - loss: 1.0802 - accuracy: 0.5098 - val_loss: 1.0227 - val_accuracy: 0.4615
# Epoch 3/200
# 4/4 [==============================] - 0s 16ms/step - loss: 1.0258 - accuracy: 0.5392 - val_loss: 1.0640 - val_accuracy: 0.3846
# Epoch 4/200
# 4/4 [==============================] - 0s 25ms/step - loss: 0.9944 - accuracy: 0.5098 - val_loss: 0.9695 - val_accuracy: 0.5385
# Epoch 5/200
# 4/4 [==============================] - 0s 20ms/step - loss: 1.0216 - accuracy: 0.5392 - val_loss: 0.9337 - val_accuracy: 0.5769
# Epoch 6/200
# 4/4 [==============================] - 0s 24ms/step - loss: 0.9279 - accuracy: 0.6176 - val_loss: 0.9017 - val_accuracy: 0.5385
# Epoch 7/200
# 4/4 [==============================] - 0s 12ms/step - loss: 0.9076 - accuracy: 0.5980 - val_loss: 0.9338 - val_accuracy: 0.5769
# Epoch 8/200
# 4/4 [==============================] - 0s 13ms/step - loss: 0.8975 - accuracy: 0.6176 - val_loss: 0.9980 - val_accuracy: 0.5769
# Epoch 9/200
# 4/4 [==============================] - 0s 14ms/step - loss: 1.0173 - accuracy: 0.4902 - val_loss: 0.9187 - val_accuracy: 0.5385
# Epoch 10/200
# 4/4 [==============================] - 0s 15ms/step - loss: 0.8712 - accuracy: 0.6471 - val_loss: 0.8738 - val_accuracy: 0.6154
# Epoch 11/200
# 4/4 [==============================] - ETA: 0s - loss: 1.0161 - accuracy: 0.50 - 0s 15ms/step - loss: 0.8654 - accuracy: 0.5882 - val_loss: 0.8584 - val_accuracy: 0.5385
# Epoch 12/200
# 4/4 [==============================] - 0s 18ms/step - loss: 0.8345 - accuracy: 0.6078 - val_loss: 0.7983 - val_accuracy: 0.6538
# Epoch 13/200
# 4/4 [==============================] - 0s 15ms/step - loss: 0.
200
# 4/4 [==============================] - 0s 14ms/step - loss: 0.9421 - accuracy: 0.5534 - val_loss: 1.0314 - val_accuracy: 0.4800
# Epoch 9/200
# 4/4 [==============================] - 0s 13ms/step - loss: 0.8575 - accuracy: 0.6311 - val_loss: 1.1319 - val_accuracy: 0.3600
# Epoch 10/200
# 4/4 [==============================] - 0s 13ms/step - loss: 0.8490 - accuracy: 0.6117 - val_loss: 1.0211 - val_accuracy: 0.5200
# Epoch 11/200
# 4/4 [==============================] - 0s 16ms/step - loss: 0.8695 - accuracy: 0.6019 - val_loss: 1.0679 - val_accuracy: 0.5600
# Epoch 12/200
# 4/4 [==============================] - 0s 19ms/step - loss: 0.9638 - accuracy: 0.5437 - val_loss: 1.3065 - val_accuracy: 0.3200
# Epoch 13/200
# 4/4 [==============================] - 0s 13ms/step - loss: 0.8709 - accuracy: 0.6117 - val_loss: 1.0829 - val_accuracy: 0.4800
# Epoch 14/200
# 4/4 [==============================] - 0s 18ms/step - loss: 0.8436 - accuracy: 0.5728 - val_loss: 1.1299 - val_accuracy: 0.4000
# Epoch 15/200
# 4/4 [==============================] - 0s 19ms/step - loss: 0.7794 - accuracy: 0.6602 - val_loss: 1.0760 - val_accuracy: 0.4800
# Epoch 16/200
# 4/4 [==============================] - 0s 19ms/step - loss: 0.8017 - accuracy: 0.6602 - val_loss: 1.1185 - val_accuracy: 0.4400
# Epoch 17/200
# 4/4 [==============================] - 0s 12ms/step - loss: 0.7473 - accuracy: 0.6893 - val_loss: 1.0466 - val_accuracy: 0.4800
# Epoch 18/200
# 4/4 [==============================] - 0s 25ms/step - loss: 0.7204 - accuracy: 0.7087 - val_loss: 1.1339 - val_accuracy: 0.4000
# Epoch 19/200
# 4/4 [==============================] - 0s 24ms/step - loss: 0.7340 - accuracy: 0.6505 - val_loss: 1.1995 - val_accuracy: 0.5200
# Epoch 20/200
# 4/4 [==============================] - 0s 13ms/step - loss: 0.7952 - accuracy: 0.6796 - val_loss: 1.1813 - val_accuracy: 0.4000
# Epoch 21/200
# 4/4 [==============================] - 0s 14ms/step - loss: 0.6926 - accuracy: 0.7087 - val_loss: 1.1048 - val_accuracy: 0.5200
# Epoch 22/200
# 4/4 [==============================] - 0s 15ms/step - loss: 0.7689 - accuracy: 0.6505 - val_loss: 1.3133 - val_accuracy: 0.3200
# Epoch 23/200
# 4/4 [==============================] - 0s 14ms/step - loss: 0.7473 - accuracy: 0.6893 - val_loss: 1.0430 - val_accuracy: 0.4800
# Epoch 24/200
# 4/4 [==============================] - 0s 28ms/step - loss: 0.6717 - accuracy: 0.6893 - val_loss: 1.3898 - val_accuracy: 0.4000
# Epoch 25/200
# 4/4 [==============================] - 0s 10ms/step - loss: 0.7636 - accuracy: 0.6990 - val_loss: 1.1169 - val_accuracy: 0.4800
# Epoch 26/200
# 4/4 [==============================] - 0s 15ms/step - loss: 0.7037 - accuracy: 0.7184 - val_loss: 1.3320 - val_accuracy: 0.3200
# Epoch 27/200
# 4/4 [==============================] - 0s 23ms/step - loss: 0.6934 - accuracy: 0.6893 - val_loss: 1.0821 - val_accuracy: 0.6000
# Epoch 28/200
# 4/4 [==============================] - 0s 12ms/step - loss: 0.6702 - accuracy: 0.7476 - val_loss: 1.1195 - val_accuracy: 0.4000
# Epoch 29/200
# 4/4 [==============================] - 0s 12ms/step - loss: 0.6388 - accuracy: 0.7282 - val_loss: 1.1922 - val_accuracy: 0.4400
# Epoch 30/200
# 4/4 [==============================] - 0s 13ms/step - loss: 0.6656 - accuracy: 0.7379 - val_loss: 1.1570 - val_accuracy: 0.5200
# Epoch 31/200
# 4/4 [==============================] - 0s 24ms/step - loss: 0.7738 - accuracy: 0.6311 - val_loss: 1.5841 - val_accuracy: 0.3200
# Epoch 32/200
# 4/4 [==============================] - 0s 25ms/step - loss: 1.0147 - accuracy: 0.5922 - val_loss: 1.0600 - val_accuracy: 0.4800
# Epoch 33/200
# 4/4 [==============================] - 0s 13ms/step - loss: 0.7447 - accuracy: 0.7184 - val_loss: 1.1804 - val_accuracy: 0.5200
# Epoch 34/200
# 4/4 [==============================] - 0s 13ms/step - loss: 0.8233 - accuracy: 0.6117 - val_loss: 1.2266 - val_accuracy: 0.4400
# Epoch 35/200
# 4/4 [==============================] - 0s 26ms/step - loss: 0.6727 - accuracy: 0.7087 - val_loss: 1.0787 - val_accuracy: 0.5200
# Epoch 36/200
# 4/4 [==============================] - 0s 24ms/step - loss: 0.6569 - accuracy: 0.7282 - val_loss: 1.1404 - val_accuracy: 0.4400
# Epoch 37/200
# 4/4 [==============================] - 0s 16ms/step - loss: 0.6849 - accuracy: 0.6796 - val_loss: 1.0915 - val_accuracy: 0.4400
# Epoch 38/200
# 4/4 [==============================] - 0s 16ms/step - loss: 0.5887 - accuracy: 0.7573 - val_loss: 1.1462 - val_accuracy: 0.4800
# Epoch 39/200
# 4/4 [==============================] - 0s 16ms/step - loss: 0.5795 - accuracy: 0.7379 - val_loss: 1.1442 - val_accuracy: 0.5600
# Epoch 40/200
# 4/4 [==============================] - 0s 18ms/step - loss: 0.5809 - accuracy: 0.7476 - val_loss: 1.2111 - val_accuracy: 0.4800
# Epoch 41/200
# 4/4 [==============================] - 0s 16ms/step - loss: 0.5817 - accuracy: 0.7573 - val_loss: 1.2220 - val_accuracy: 0.5200
# Epoch 42/200
# 4/4 [==============================] - 0s 20ms/step - loss: 0.6278 - accuracy: 0.7282 - val_loss: 1.1706 - val_accuracy: 0.5600
# Epoch 43/200
# 4/4 [==============================] - 0s 16ms/step - loss: 0.6718 - accuracy: 0.7087 - val_loss: 1.2335 - val_accuracy: 0.5600
# Epoch 44/200
# 4/4 [==============================] - 0s 15ms/step - loss: 0.7114 - accuracy: 0.6990 - val_loss: 1.5697 - val_accuracy: 0.5200
# Epoch 45/200
# 4/4 [==============================] - 0s 12ms/step - loss: 0.7183 - accuracy: 0.7379 - val_loss: 1.2279 - val_accuracy: 0.3200
# Epoch 46/200
# 4/4 [==============================] - 0s 13ms/step - loss: 0.6200 - accuracy: 0.7573 - val_loss: 1.1255 - val_accuracy: 0.4800
# Epoch 47/200
# 4/4 [==============================] - 0s 12ms/step - loss: 0.5869 - accuracy: 0.7961 - val_loss: 1.1517 - val_accuracy: 0.5200
# Epoch 48/200
# 4/4 [==============================] - 0s 12ms/step - loss: 0.5319 - accuracy: 0.7670 - val_loss: 1.2345 - val_accuracy: 0.5600
# Epoch 49/200
# 4/4 [==============================] - 0s 14ms/step - loss: 0.5281 - accuracy: 0.7961 - val_loss: 1.2916 - val_accuracy: 0.4800
# Epoch 50/200
# 4/4 [==============================] - 0s 14ms/step - loss: 0.5440 - accuracy: 0.7573 - val_loss: 1.3949 - val_accuracy: 0.5600
# Epoch 51/200
# 4/4 [==============================] - 0s 14ms/step - loss: 0.5150 - accuracy: 0.7670 - val_loss: 1.4340 - val_accuracy: 0.4400
# Epoch 52/200
# 4/4 [==============================] - 0s 18ms/step - loss: 0.5143 - accuracy: 0.7670 - val_loss: 1.3752 - val_accuracy: 0.4800
# Epoch 53/200
# 4/4 [==============================] - 0s 13ms/step - loss: 0.5284 - accuracy: 0.7670 - val_loss: 1.9189 - val_accuracy: 0.4800
# Epoch 54/200
# 4/4 [==============================] - 0s 12ms/step - loss: 0.8678 - accuracy: 0.6311 - val_loss: 1.9611 - val_accuracy: 0.4000
# Epoch 55/200
# 4/4 [==============================] - 0s 20ms/step - loss: 0.7738 - accuracy: 0.6699 - val_loss: 1.2129 - val_accuracy: 0.6000
# Epoch 56/200
# 4/4 [==============================] - 0s 11ms/step - loss: 0.5214 - accuracy: 0.8155 - val_loss: 1.1398 - val_accuracy: 0.5200
# Epoch 57/200
# 4/4 [==============================] - 0s 12ms/step - loss: 0.4967 - accuracy: 0.8058 - val_loss: 1.1568 - val_accuracy: 0.5200
# Epoch 58/200
# 4/4 [==============================] - 0s 20ms/step - loss: 0.4711 - accuracy: 0.8058 - val_loss: 1.1805 - val_accuracy: 0.5600
# Epoch 59/200
# 4/4 [==============================] - 0s 11ms/step - loss: 0.5342 - accuracy: 0.7961 - val_loss: 1.1846 - val_accuracy: 0.5600
# Epoch 60/200
# 4/4 [==============================] - 0s 15ms/step - loss: 0.4005 - accuracy: 0.8641 - val_loss: 1.2626 - val_accuracy: 0.5600
# 1/1 [==============================] - 0s 24ms/step - loss: 1.2626 - accuracy: 0.5600
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4413 - accuracy: 0.8252
# -0.9561055064201355

# %% [markdown]
# Breeding two individuals to create a child. Mutation is automatically performed during this

# %%
example_individual_two = Individual(gene_set_list)
print(f"Breeding {example_individual} with {example_individual_two}")
child = breed_individuals(example_individual, example_individual_two)
print(f"Created child {child}")
# Out:
# Breeding Individual(['[4, 7, 4, 0.68]']) with Individual(['[4, 7, 4, 0.68]', '[4, 2, 4, 0.43]'])
# Created child Individual(['[4, 7, 8, 0.68]'])

# %% [markdown]
# ## Population

# %% [markdown]
# A Population is a collection of Individual classes. This can be created using a list of GeneParameter classes

# %%
gene_parameters = [params1, params2]
pop = Population(best_sample, lucky_few, population_size, 
                 number_of_children, gene_parameters, 
                 maximise_scores = True)
pop
# Out:
# Population(4, 2, 12, 4, [GeneParameters(lower=1, upper=10, centres='{1, 6, 7, 8, 9, 15, 16, 17}', neighbours='{1, 6, 7, 8, 9, 15, 16, 17}', mu=0, mu_hat=0, nu=2, nu_hat=0, mutation_chance=0.5, min_cutoff=4, max_cutoff=10, min_sigma=0.1, max_sigma=0.9, message_steps=8), GeneParameters(lower=1, upper=5, centres='{1, 6, 7, 8, 9, 15, 16, 17}', neighbours='{1, 6, 7, 8, 9, 15, 16, 17}', mu=0, mu_hat=0, nu=2, nu_hat=0, mutation_chance=0.5, min_cutoff=4, max_cutoff=5, min_sigma=0.1, max_sigma=0.9, message_steps=10)], True)

# %% [markdown]
# To initialise the population

# %%
pop.initialise_population()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-947ac7688bfc> in <module>
# ----> 1 pop.initialise_population()
#
# ~/Projets/SOAP_GAS_TMS/genetic_algorithm.py in initialise_population(self)
#     486                              gene_parameters in self.list_of_gene_parameters]
#     487             self.population.add(Individual(gene_set_list))
# --> 488         self.get_population_scores()
#     489         write_to_outfile(f"Initial population of size {self.population_size} generated")
#     490
#
# ~/Projets/SOAP_GAS_TMS/genetic_algorithm.py in get_population_scores(self)
#     554         counter = 1
#     555         for individual in self.population:
# --> 556             write_to_outfile(f"Getting score for individual {counter} of "
#     557                   f"{self.population_size}")
#     558             counter += 1
#
# NameError: name 'write_to_outfile' is not defined

# %% [markdown]
# If you want a way of neatly seeing what individuals are in the population

# %%
pop.print_population()

# %% [markdown]
# The next generation can then be generated

# %%
pop.next_generation()
pop.print_population()

# %% [markdown]
# So to run the full GA

# %%
for _ in range(num_gens):
    pop.next_generation()
pop.print_population()

# %% [markdown]
# ## BestHistory

# %% [markdown]
# BestHistory is a class to store the history and check convergence criteria. So the entire GA can be run, printed, and saved using the following code snippet:

# %%
hist = BestHistory(early_stop, early_number, min_generations)
pop = Population(best_sample, lucky_few, population_size, 
                 number_of_children, gene_parameters, 
                 maximise_scores = True)

for gen in range(num_gens):
    if hist.converged:
        break
    print(f"Generation {gen}")
    pop.next_generation()
    hist.append(pop)
    write_to_outfile("-------")

# %% [markdown]
# There now exists the entire history of the best Individuals throughout each generation that can be saved and easily accessed.

# %%
vars(hist)

# %% [markdown]
# ### Running the GA as a script

# %% [markdown]
# To run the GA as a script, you just need an input file. See 'SOAP_GAS_TMS/input.py' for an example of the format.
#
# Then to run the GA with this input file, run 'python genetic_algorithm.py \<input file name without .py extension>'
#
# Running the script creates two files, out_\<input file name>.txt and history_\<input file name>.pkl
#
# If these files already exist, the old ones will be backed up and new ones created.
#
# The out file contains a log of everything happening in the GA.
# The history file contains a BestHistory object containing the best individuals throughout the GA.

# %% [markdown]
# ### Testing

# %%
from genetic_algorithm import *
input_parameters = __import__('input')

# %%
gene_parameters = [GeneParameters(**params) for params in input_parameters.descList]

# %%
example_gene_set = [params.make_gene_set() for params in gene_parameters]

# %%
example_gene_set[0].cutoff = 5

# %%
example_individual = Individual(example_gene_set)

# %%
# example_individual.cutoff = 5
s = 'soap average cutoff=3 l_max=2 n_max=2 atom_sigma=0.52 n_Z=7 Z={8, 7, 6, 1, 16, 17, 9} n_species=7 species_Z={8, 7, 6, 1, 16, 17, 9} nu_R=1 nu_S=1'
example_individual

# %%
example_individual.soap_string_list = [s]

# %%
vars(example_individual)

# %%
conf_s, data = get_conf()
example_individual.comp_soaps(conf_s, data)

# %%
example_individual.get_score()

# %%
example_individual.score

# %%
# example_individual.soap_string_list = ['soap average cutoff=5 l_max=6 n_max=6 atom_sigma=0.22 n_Z=1 Z={6} n_species=1 species_Z={6} mu=0 mu_hat=1 nu=1 nu_hat=0'

# %%
# for mol in conf_s[:5]:
#         soap = []
#         a_soap = descriptors.Descriptor(s).calc(mol)['data']

# %%
mol = conf_s[1]

# %%
a = descriptors.Descriptor(s).calc(mol)['data']

# %%
a.shape

# %%
conf_s, data = get_conf()

# %%
column_names = data.columns
column_names

# %%
try:
    if column_names[1].upper().strip() == 'TARGET':
        regression = True
    elif column_names[1].upper().strip() == 'CLASS':
        regression = False
except:
    raise TypeError("Your database.csv file isc not of the correct "
                     "format. Please read the docs.")

# %%
from genetic_algorithm import *
input_parameters = __import__('input')

conf_s, data = get_conf()
soap_array = []
targets = data.iloc[:, 1].values
s = 'soap average cutoff=3 l_max=2 n_max=2 atom_sigma=0.52 n_Z=7 Z={8, 7, 6, 1, 16, 17, 9} n_species=7 species_Z={8, 7, 6, 1, 16, 17, 9} nu_R=1 nu_S=1'
soap_string_list = [s]
soap_string_list

# %%
soap_array = []
for mol in conf_s:
    soap = []
    for parameter_string in soap_string_list:
        soap += list(descriptors.Descriptor(parameter_string).calc(mol)['data'][0])
        soap_array.append(soap)

# %%
len(soap_array)

# %%
vars(mol)

# %%
conf_s[45:46]

# %%
data[45:46]

# %%
soaps = example_individual.soaps
cv = RepeatedKFold(n_splits=5, n_repeats=1, random_state=35)
for train_index, test_index in cv.split(soaps):
    estimator = build_model(soaps, regression=False)
    Y = example_individual.targets
    encoder = LabelEncoder()
    encoder.fit(Y)
    encoded_Y = encoder.transform(Y)
    y = to_categorical(encoded_Y)

    X_train, X_test, X_scaler = scale_data(soaps[train_index],
                                           soaps[test_index])
    y_train, y_test = y[train_index], y[test_index]
    # res = scorer_NN_class(estimator, X_train, X_test, y_train, y_test)

# %%
callback = EarlyStopping(monitor='val_loss', patience=50)
# y_train = np.argmax(y_train, axis=1)
# y_test = np.argmax(y_test, axis=1)
estimator.fit(X_train, y_train, callbacks=[callback], validation_data=(
    X_test, y_test), epochs=200, verbose=True)
y_test_pred = estimator.predict(X_test)
y_train_pred = estimator.predict(X_train)
_, test_accuracy = estimator.evaluate(X_test, y_test_pred)
_, train_accuracy = estimator.evaluate(X_train, y_train_pred)
y_test_pred = np.argmax(y_test_pred, axis=1)
y_train_pred = np.argmax(y_train_pred, axis=1)
score = -1 * (test_accuracy + (0.5 * train_accuracy))
res = [('scores', score), ('y_train_actual', y_train), \
      ('y_test_actual', y_test), ('y_train_predictions', y_train_pred),
           ('y_test_predictions', y_test_pred)]

# %%
res

# %%
y_train.shape

# %%
# estimator.fit(X_train, y[, callbacks=[callback], validation_data=(
#     X_test, y_test), epochs=200, verbose=True)
